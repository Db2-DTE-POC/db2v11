# %% [markdown]
# [![](./media/dte-header.jpg)](https://www.ibm.com/demos/collection/db2-database/)
# <a id="top">

# %% [markdown]
# # Db2 11 Features and Functions
# Welcome to this Db2 lab that highlights the new features of Db2 11. This system demonstrates the new Db2 11 features through the use of Jupyter notebooks. If you are not familiar with the use of Jupyter notebooks or Db2 Magic commands, the following notebooks will guide you through their usage.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">An Introduction to Jupyter Notebooks</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              If you are not familiar with the use of Jupyter notebooks or Python, the following notebook
#              will guide you through their usage.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/An_Introduction_to_Jupyter_Notebooks.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">Db2 Magic Commands</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              Db2 Magic commands are used in all of the notebooks used in this lab.
#              The following notebook provides a tutorial on basics of using the Db2 magic commands.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_Jupyter_Extensions_Tutorial.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# These set of notebooks cover some of the new SQL functionality that was delivered in Db2 11.1. Note that two of the notebooks cover the JSON functions that were added to Db2 in 10.5 and officially published in 11.1. These functions are used to support the MongoDB compatibility features in Db2, but are not part of the SQL standard. If you want to use the official JSON functions then you need to use Db2 11.5.

# %% [markdown]
# <!-- Row 1 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Oracle, Open Source and Netezza Compatibility
#         </div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Description -->
# Db2 11 introduces some additional data type and function compatibility that will reduce some of the migration effort required when porting from other systems.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Compatibility_Features.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Regular Expressions
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Db2 11 introduced extended support for regular expressions. Regular expressions allow you to do very complex pattern matching in character strings. Regular expression have a rich syntax that gives you much more flexibility in searching.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 15min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Regular_Expressions.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Row and Column Access Control
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Row permissions and column masks are two new database concepts that address the shortcomings of traditional security methods. These new features act as a second layer of security that complements the table privileges security model available in prior releases of Db2.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Row_and_Column_Access_Control.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# <!-- Row 2 -->
# </div>
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Updated Statistical Functions</div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Abstract -->
# Db2 already has a variety of Statistical functions built in. In Db2 11.1, a number of new functions have been added including ones that improve compatibility with other SQL implementations.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Statistical_Functions.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Time and Date Functions
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Db2 11 introduced extended support for regular expressions. Regular expressions allow you to do very complex pattern matching in character strings. Regular expression have a rich syntax that gives you much more flexibility in searching.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 15min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Time_and_Date_Functions.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON Features (SYSTOOLS)
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# There are a number of routines are that are built-in to Db2 that are used to manipulate JSON documents. These routines were originally used by the internal API's of Db2 for managing the MongoDB interface. These routines have now been made available for use in Db2.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 20min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_JSON_Features_SYSTOOLS.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>
# <!-- Row 3 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Advanced Db2 JSON Techniques (SYSTOOLS)
#         </div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Abstract -->
# The basics of using JSON within Db2 were covered in a previous notebook. This notebook will cover some of the advanced techniques that are required to access arrays and structures that may be nested within a JSON document.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 15min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/Db2_11.1_Advanced_Db2_JSON_Techniques_SYSTOOLS.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Db2 Version 11 Highlights eBook
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This book was written to highlight many of the new features and functions that are now available in the Db2 V11, without you having to search through various forums, blogs, and online manuals.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 2hr
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="http://localhost:8888/notebooks/media/Db2V11-ebook.pdf">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# #### Questions and Comments: George Baklarz [baklarz@ca.ibm.com]
